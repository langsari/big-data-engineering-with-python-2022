# %%
import pandas as pd

# %%
u = pd.read_csv("C:/Users/aminah/OneDrive/Desktop/csv/quran_surah.csv")

# %%
u.head()
# Out:
#    surah         arabic        latin              english  sajda  ayah  \
# 0      1   سورة الفاتحة    Al-Fatiha          The Opening      0     7
# 1      2    سورة البقرة    Al-Baqara              The Cow      0   286
# 2      3  سورة آل عمران  Aal-e-Imran  The family of Imran      0   200
# 3      4    سورة النساء      An-Nisa            The Women      0   176
# 4      5   سورة المائدة     Al-Maeda     The Table Spread      0   120
#
#        types
# 0    Makiyah
# 1  Madaniyah
# 2  Madaniyah
# 3  Madaniyah
# 4  Madaniyah

# %%
u
# Out:
#       id      name transliteration         translation     type  total_verses  \
# 0      1   الفاتحة      Al-Fatihah          The Opener   meccan             7
# 1      2    البقرة      Al-Baqarah             The Cow  medinan           286
# 2      3  آل عمران      Ali 'Imran     Family of Imran  medinan           200
# 3      4    النساء         An-Nisa           The Women  medinan           176
# 4      5   المائدة      Al-Ma'idah    The Table Spread  medinan           120
# ..   ...       ...             ...                 ...      ...           ...
# 109  110     النصر         An-Nasr  The Divine Support  medinan             3
# 110  111     المسد        Al-Masad      The Palm Fiber   meccan             5
# 111  112   الإخلاص       Al-Ikhlas       The Sincerity   meccan             4
# 112  113     الفلق        Al-Falaq        The Daybreak   meccan             5
# 113  114     الناس          An-Nas             Mankind   meccan             6
#
# ...

# %%
import psycopg2

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=project user=postgres password=admin port=12345")

# %%
cur = conn.cursor()

# %%
conn.set_session(autocommit=True)

# %%
try: 
    cur.execute("create database quran")
except psycopg2.Error as e:
    print(e)
# Out:
# database "quran" already exists

# %%
try: 
    conn.close()
except psycopg2.Error as e:
    print(e)
  
try: 
    conn = psycopg2.connect("host=127.0.0.1 dbname=project user=postgres password=admin port=12345")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)
    
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)

conn.set_session(autocommit=True)

# %%
try: 
    cur.execute("CREATE TABLE IF NOT EXISTS quran_surah (surah int, arabic int, latin varchar, english varchar, sajda int, ayah int, types varchar);")
except psycopg2.Error as e: 
    print("Error: Issue creating table")
    print (e)

# %%
# Out:
# Error: Issue import csv
# could not open file "C:/Users/aminah/OneDrive/Desktop/csv/quran_surah.csv" for reading: Permission denied
# HINT:  COPY FROM instructs the PostgreSQL server process to read a file. You may want a client-side facility such as psql's \copy.
