# %% [markdown]
# # Demos 1 : Reading and Writing files in Python

# %% [markdown]
# ### working with data need libraries

# %% [markdown]
# install `Faker` package
#
# `conda install -c conda-forge faker`
#
# or
#
# `pip install Faker`

# %% [markdown]
# ### Writing and reading CSVs

# %% [markdown]
# Writing CSVs using the Python CSV Library. Create 1,000 records data and save to CSV format

# %%
from faker import Faker

# %%
from faker import Faker
import csv

output=open('data-generator-faker.csv','w')

fake=Faker()
header=['name','age','street','city','state','zip','lng','lat']
mywriter=csv.writer(output)
mywriter.writerow(header)

for r in range(1000):
    mywriter.writerow([fake.name(),
                       fake.random_int(min=18, max=80, step=1), 
                       fake.street_address(), 
                       fake.city(),
                       fake.state(),
                       fake.zipcode(),
                       fake.longitude(),
                       fake.latitude()])
output.close()

# %% [markdown]
# Reading CSVs by python

# %%
import csv

with open('data-generator-faker.csv') as f:
    myreader=csv.DictReader(f)
    headers=next(myreader)
    for row in myreader:
        print(row['name'])
# Out:
# Bethany Martinez
# Sarah Perkins
# Matthew Brown
# Evelyn Thomas
# Derrick Montgomery
# Tracy Roth
# Samantha Henderson
# William Burgess
# Alexis Leach
# Julia Watkins
# Clarence Jones
# Dr. Jerry Hanson
# Kristi Eaton
# Trevor Johnson
# William Nicholson
# Tara Harper
# Edwin Thompson
# Tracy Chapman
# Tyler Dillon
# Melissa Smith
# Samantha Phillips
# Jennifer Peterson
# Tricia Robbins
# Dustin Perez
# Helen Floyd
# Kathryn Pittman
# Kyle Best
# Jason Morgan
# Christopher Velasquez
# Maurice Hensley
# Cody Barrett
# Harold Swanson
# Ms. Cassidy Kline
# Drew Shaffer
# Andrew Brock
# Brandon Rowe
# Michael Becker
# William Kemp Jr.
# Jeremy Clark
# Kristen King
# Amy Fletcher
# Michael Stein
# Justin Torres
# Jeffery Richard
# Christopher Fitzgerald
# Ana Ortiz
# Matthew Massey
# Dana Snyder
# Michael Cunningham
# Richard Robbins
# Adrian Kane
# Sheena Bell
# Erica Freeman
# Phillip Lee
# Kelly Leonard
# Taylor Coleman
# Peter Richards
# Christian Owens
# David Stone
# Alan Gill
# Danny Cruz
# Darrell Anderson
# Nicole Walls
# Michael Gonzales
# Kyle Herman
# Rachel Reynolds
# Melanie Sanchez
# Julie Reynolds
# Brian Rivera
# Matthew Miller
# Devon Browning
# Lisa Lawson
# Kyle Thompson
# Angela Hughes
# Hannah Williams
# Aaron Robertson
# Mr. Mark Nguyen
# Emily Kennedy
# Regina Keller
# Brenda Skinner
# Danielle Berry
# Brent Owens
# Ronald Smith
# Sandra Hunt
# Dylan Ballard
# Travis Reyes
# Natalie Garrison
# Elizabeth Delacruz
# Karen Williams
# Mark Duke
# William Alvarez
# Alex Hansen
# Bailey Hancock
# Monique Alvarez
# Jennifer Wilson
# Lisa Perez
# Nicole Adams
# Melanie Ellis
# William Smith
# David Carter
# Amy Allen
# Michael Nelson Jr.
# Joshua Myers
# Stacey Jones
# Connie Turner
# Melanie Holmes
# Amanda Salinas
# Kenneth Hicks
# Jill Salazar
# Sierra Garcia
# Felicia Barker
# Stephen Gilbert
# Joel Miller
# Connie Thomas
# Matthew Thompson
# Bill Duarte
# Jose Mcfarland
# Jennifer Taylor
# Valerie Smith
# Christian Garrett
# Robert Taylor
# Eric Vega
# Frank Young
# Morgan Rivera
# Hannah Long
# Richard Gonzalez
# Stacy Stone
# Kimberly Chaney
# Karl Rivera
# Justin Carey
# Katrina Brewer
# Patrick Reyes
# Mary Carr
# Mary Torres
# Mckenzie Chapman
# Gabriel Herrera
# Michelle Torres PhD
# Chad Lindsey
# Julie Reyes
# Katherine Vasquez
# Stephanie Lewis
# Lisa Rodriguez
# Daniel Salazar
# Michael Lewis
# Jessica Gibson
# Claire Castro
# Lori Walter
# David Rodriguez
# Rachel Duncan
# Mary Warren
# Michael Robertson
# Haley Ellis
# Mrs. Monica Lopez DDS
# Christy Martin
# David Hodges
# Zachary Price
# Mark Burch
# Wendy Bush
# Kenneth Scott
# Anna Santos
# John Harper
# Jennifer Wilkinson
# Valerie Gomez
# Brittany Jones
# Lauren Davis
# Nicole James
# Susan Medina
# Megan Marshall
# Christopher Keller
# Rebekah Gordon
# Donna Silva
# Taylor Thompson
# Jeremy Robinson
# Miranda Miller
# Elizabeth Allen
# Jennifer Bradley
# David Williams
# Lisa Maxwell
# Richard Mathews
# Brandon Blevins
# Susan Bowers
# Rebecca Luna
# Matthew Scott
# Kathryn Hart
# Glenda Barker
# Daniel Roberson
# Daniel Phillips
# Brianna Nguyen
# Juan Sheppard
# Guy Murray
# Joann Scott
# Angela Martin
# Dawn Davis
# Leslie Stewart
# Michelle Parker MD
# Timothy Brown
# Kenneth Garcia
# Jeffery Foster
# Erin Clarke
# Zachary Miller
# Tracey Long
# Joshua Carlson
# Dylan Shelton
# Gary Smith
# Ricky Moore

# %% [markdown]
# ### Reading and writing CSVs using pandas DataFrames

# %% [markdown]
# install `pandas` package

# %% [markdown]
# `pip install pandas`

# %%
import pandas as pd
df = pd.read_csv('data-generator-faker.csv')

# %%
df.head(10)
# Out:
#                  name  age                          street              city  \
# 0        Wendy Peters   70  668 Robert Junctions Suite 919     Williamsmouth
# 1    Bethany Martinez   73                13242 Cox Meadow        Lake Dylan
# 2       Sarah Perkins   20             4220 Matthew Island  West Michaeltown
# 3       Matthew Brown   18        6628 Flores Dam Apt. 186          New Ryan
# 4       Evelyn Thomas   39           11873 Adam Expressway   East Samuelland
# 5  Derrick Montgomery   69              9988 Sanford Walks        Bettyhaven
# 6          Tracy Roth   60                41241 Jimmy Cape        Robertberg
# 7  Samantha Henderson   50             942 Cathy Mountains         Davidview
# 8     William Burgess   43                968 Antonio Fort          Colestad
# 9        Alexis Leach   39   31066 Miller Tunnel Suite 310   Samanthachester
#
#             state    zip         lng        lat
# 0         Georgia  45227 -159.668739  31.029393
# 1         Indiana  42157   21.483181 -55.366385
# 2            Utah  79262   95.539944   6.915683
# 3    South Dakota  46123 -125.118068   6.593683
# 4     Mississippi  80578   46.444284 -76.839136
# 5       Wisconsin  69524 -133.131484 -52.598728
# 6            Utah  96292  -14.315962  88.745744
# 7          Hawaii  38550  -53.322235 -75.068396
# 8  South Carolina  14858  164.142611 -84.991730
# 9         Alabama  41174   72.043399  72.305274

# %% [markdown]
# ### Writing JSON with Python

# %% [markdown]
# Write JSON using Python and the standard library

# %%
from faker import Faker
import json

output=open('data-generator-faker.json','w')

fake=Faker()
alldata={}
alldata['records']=[]

for x in range(1000):
    data={"name":fake.name(),
          "age":fake.random_int(min=18, max=80, step=1),
          "street":fake.street_address(),
          "city":fake.city(),
          "state":fake.state(),
          "zip":fake.zipcode(),
          "lng":float(fake.longitude()),
          "lat":float(fake.latitude()),
          "code":fake.phone_number()}
    alldata['records'].append(data)
json.dump(alldata,output)

# %% [markdown]
# Reading JSON

# %%
import json
with open("data-generator-faker.json",'r') as f:
    data=json.load(f)
print(type(data))
print(data['records'][0]['name'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4440\358554485.py in <module>
#       1 import json
#       2 with open("data-generator-faker.json",'r') as f:
# ----> 3     data=json.load(f)
#       4 print(type(data))
#       5 print(data['records'][0]['name'])
#
# ~\anaconda3\Anaconda\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~\anaconda3\Anaconda\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\Anaconda\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\Anaconda\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 188367 (char 188366)

# %%
import pandas as pd
df = pd.read_json('data-generator-faker.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4440\349447767.py in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_json('data-generator-faker.json')
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     610
#     611     with json_reader:
# --> 612         return json_reader.read()
#     613
#     614
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\io\json\_json.py in read(self)
#     744                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     745         else:
# --> 746             obj = self._get_object_parser(self.data)
#     747         self.close()
#     748         return obj
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     766         obj = None
#     767         if typ == "frame":
# --> 768             obj = FrameParser(json, **kwargs).parse()
#     769
#     770         if typ == "series" or obj is None:
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     878             self._parse_numpy()
#     879         else:
# --> 880             self._parse_no_numpy()
#     881
#     882         if self.obj is None:
#
# ~\anaconda3\Anaconda\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1131         if orient == "columns":
#    1132             self.obj = DataFrame(
# -> 1133                 loads(json, precise_float=self.precise_float), dtype=None
#    1134             )
#    1135         elif orient == "split":
#
# ValueError: Expected object or value

# %% [markdown]
# ## Working with Databases

# %% [markdown]
# ### Inserting and extracting relational data in Python

# %% [markdown]
# 1. Creating a PostgreSQL database and tables in pgadmin4 that consist of
#
#     a) name: text
#
#     b) id: integer
#
#     c) street: text
#
#     d) city: text
#
#     e) zip: text
#
#
# 2. Inserting data into PostgreSQL
#
#     Installing psycopg2
#
#     Connecting to PostgreSQL with Python
#
#     Inserting data
#
#     Inserting multiple records

# %%
import psycopg2 as db

# %%
conn_string="dbname='aj.kholid' host='localhost' user='postgres' password='admin'"

# %% [markdown]
# conneting to PostgreSQL

# %%
import psycopg2 as db

conn_string="dbname='aj.kholid' host='localhost' user='postgres' password='admin'"

conn=db.connect(conn_string)

cur=conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19476\1113757859.py in <module>
#       3 conn_string="dbname='aj.kholid' host='localhost' user='postgres' password='admin'"
#       4
# ----> 5 conn=db.connect(conn_string)
#       6
#       7 cur=conn.cursor()
#
# ~\anaconda3\Anaconda\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?

# %% [markdown]
# Inserting Data

# %%
query = "insert into users (id,name,street,city,zip) values({},'{}','{}','{}','{}')".format(1,'Big Bird','Sesame Street','Fakeville','12345')
print(cur.mogrify(query))

query2 = "insert into users (id,name,street,city,zip) values(%s,%s,%s,%s,%s)"
data=(1,'Big Bird','Sesame Street','Fakeville','12345')
print(cur.mogrify(query2,data))

cur.execute(query2,data)
conn.commit()

# %% [markdown]
# Inserting multiple records

# %%
import psycopg2 as db
from faker import Faker

fake=Faker()
data=[]
i=2

for r in range(1000):
    data.append((i,fake.name(),fake.street_address(), fake.city(),fake.zipcode()))
    i+=1

data_for_db=tuple(data)

print(data_for_db)

# %%
import psycopg2 as db
from faker import Faker

fake=Faker()
data=[]
i=2

for r in range(1000):
    data.append((i,fake.name(),fake.street_address(), fake.city(),fake.zipcode()))
    i+=1

data_for_db=tuple(data)

# print(data_for_db)

conn_string="dbname='dataengineering' host='localhost' user='postgres' password='admin'"
conn=db.connect(conn_string)
cur=conn.cursor()

query = "insert into users (id,name,street,city,zip) values(%s,%s,%s,%s,%s)"
# print(cur.mogrify(query,data_for_db[1]))

cur.executemany(query,data_for_db)
conn.commit()
query2 = "select * from users"

cur.execute(query2)
print(cur.fetchall())

# %% [markdown]
# ### Extracting data from PostgreSQL

# %%
import psycopg2 as db

conn_string="dbname='dataengineering' host='localhost' user='postgres' password='admin'"
conn=db.connect(conn_string)
cur=conn.cursor()

query = "select * from users"
cur.execute(query)

print(cur.fetchone())
print(cur.rowcount)
print(cur.rownumber)
print(cur.fetchmany(3))
print(cur.rownumber)

f=open('fromdb.csv','w')
conn=db.connect(conn_string)
cur=conn.cursor()
cur.copy_to(f,'users',sep=',')
f.close()

f=open('fromdb.csv','r')
print(f.read())

# %% [markdown]
# ### Extracting data with DataFrames

# %%
import psycopg2 as db
import pandas as pd

conn_string="dbname='dataengineering' host='localhost' user='postgres' password='admin'"
conn=db.connect(conn_string)

df=pd.read_sql("select * from users", conn)

df.head(10)
# print(df.head())
# print(df['city'].value_counts())

# %%
df.head(10)
